# %% [markdown]
# ### 1. How do you distinguish between shutil.copy() and shutil.copytree()?

# %% [markdown]
# - shutil.copy() is function which will copy a single file
# - shutil.copytree() is function which will copy an entire folder contained in the source.

# %%
# eg : shutil.copy()

import shutil

source = r'C:\Users\ARYAN\Desktop\b\textfile.txt'

dest = r'C:\Users\ARYAN\Desktop\a'

shutil.copy(source,dest)
# Out:
# 'C:\\Users\\ARYAN\\Desktop\\a\\textfile.txt'

# %%
# eg : shutil.copytree()

import shutil

source = r'C:\Users\ARYAN\Desktop\b'

# make sure that the dest directory should not exist :
dest = r'C:\Users\ARYAN\Desktop\c'

shutil.copytree(source,dest)
# Out:
# 'C:\\Users\\ARYAN\\Desktop\\c'

# %% [markdown]
# ### 2. What function is used to rename files??

# %% [markdown]
# - Function to rename the file is os.rename()

# %%
# eg :

import os

source = r'C:\Users\ARYAN\Desktop\b\textfile.txt'

# dest have the new file name :
dest = r'C:\Users\ARYAN\Desktop\b\text1.txt'

os.rename(source,dest)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3. What is the difference between the delete functions in the send2trash and shutil modules?

# %% [markdown]
# - The send2trash functions will move a file or folder to the recycle bin
# - shutil functions will permanently delete files and folders.

# %% [markdown]
# ### 4.ZipFile objects have a close() method just like File objects’ close() method. What ZipFile method is equivalent to File objects’ open() method?

# %% [markdown]
# The zipfile.ZipFile() function is equivalent to the open() function as it takes the same arguments like filename and mode to open the zip file.

# %% [markdown]
# ### 5. Create a programme that searches a folder tree for files with a certain file extension (such as .pdf or .jpg). Copy these files from whatever location they are in to a new folder.

# %%
import os, shutil

sourcePath = input('Enter the absolute path of the source folder: ')
fileExtType = input('Enter the type of file to copy (such as .pdf or .jpg): ').lower()
destPath = input('Enter the absolute path of the destination folder: ')

for foldername, subfolders, filenames in os.walk(sourcePath):
    for filename in filenames:
        if filename.lower().endswith(fileExtType):
            copySourcePath = os.path.join(foldername, filename)
            shutil.copy(copySourcePath, destPath)
        else:
            continue
# Out:
# Enter the absolute path of the source folder: C:\Users\ARYAN\pdf2
# Enter the type of file to copy (such as .pdf or .jpg): .pdf
# Enter the absolute path of the destination folder: C:\Users\ARYAN\pdf

# %% [markdown]
# ![image.png](attachment:image.png)
